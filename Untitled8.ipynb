# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

veriseti=pd.read_csv("dataset.csv")
veriseti=veriseti.rename(columns={"country_code":"Ülke Kodu","country_name":"Ulke Adı","year":"Yıl"})
veriseti=veriseti.rename(columns={"crude_birth_rate":"Kaba Doğum Oranı","crude_death_rate":"Gerçek Ölüm Oranı"})
veriseti=veriseti.rename(columns={"net_migration":"Net Göç","rate_natural_increase":"Doğal Artış Oranı"})
veriseti=veriseti.rename(columns={"growth_rate":"Büyüme Oranı"})
veriseti
# Out:
#       Ülke Kodu         Ulke Adı   Yıl  Kaba Doğum Oranı  Gerçek Ölüm Oranı  \
# 0            SI         Slovenia  2036              7.59              14.65
# 1            SI         Slovenia  2022              7.52              12.28
# 2            SI         Slovenia  2023              7.43              12.41
# 3            SI         Slovenia  2024              7.35              12.55
# 4            SI         Slovenia  2025              7.30              12.68
# ...         ...              ...   ...               ...                ...
# 15104        BP  Solomon Islands  2000             34.93               4.53
# 15105        BP  Solomon Islands  1999             35.48               4.61
# 15106        BP  Solomon Islands  1998             35.98               4.70
# 15107        BP  Solomon Islands  1997             36.44               4.79
# 15108        BP  Solomon Islands  1995             37.17               4.97
#
#        Net Göç  Doğal Artış Oranı  Büyüme Oranı
# ...

# %%
veriseti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15109 entries, 0 to 15108
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ülke Kodu          15109 non-null  object
#  1   Ulke Adı           15109 non-null  object
#  2   Yıl                15109 non-null  int64
#  3   Kaba Doğum Oranı   15109 non-null  float64
#  4   Gerçek Ölüm Oranı  15109 non-null  float64
#  5   Net Göç            15109 non-null  float64
#  6   Doğal Artış Oranı  15109 non-null  float64
#  7   Büyüme Oranı       15109 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 944.4+ KB

# %%
veriseti.drop('Ülke Kodu', inplace=True, axis=1)

# %%
veriseti
# Out:
#               Ulke Adı   Yıl  Kaba Doğum Oranı  Gerçek Ölüm Oranı  Net Göç  \
# 0             Slovenia  2036              7.59              14.65     0.23
# 1             Slovenia  2022              7.52              12.28     0.32
# 2             Slovenia  2023              7.43              12.41     0.31
# 3             Slovenia  2024              7.35              12.55     0.31
# 4             Slovenia  2025              7.30              12.68     0.30
# ...                ...   ...               ...                ...      ...
# 15104  Solomon Islands  2000             34.93               4.53    -2.51
# 15105  Solomon Islands  1999             35.48               4.61    -2.58
# 15106  Solomon Islands  1998             35.98               4.70    -2.45
# 15107  Solomon Islands  1997             36.44               4.79    -2.31
# 15108  Solomon Islands  1995             37.17               4.97    -2.01
#
#        Doğal Artış Oranı  Büyüme Oranı
# ...

# %%
veriseti.describe()
# Out:
#                 Yıl  Kaba Doğum Oranı  Gerçek Ölüm Oranı       Net Göç  \
# count  15109.000000      15109.000000       15109.000000  15109.000000
# mean    2016.748891         20.645532           9.137688     -0.041234
# std       20.220176         11.714597           4.409634     29.716751
# min     1950.000000          3.620000           1.530000   -831.810000
# 25%     2001.000000         11.160000           6.230000     -2.130000
# 50%     2017.000000         16.690000           8.130000     -0.090000
# 75%     2034.000000         27.890000          11.050000      1.210000
# max     2050.000000         58.740000          97.080000   1693.010000
#
#        Doğal Artış Oranı  Büyüme Oranı
# count       15109.000000  15109.000000
# mean            1.150771      1.109136
# std             1.114461      3.155930
# min            -6.383000   -168.944000
# 25%             0.250000      0.223000
# 50%             1.038000      0.938000
# 75%             2.075000      1.989000
# ...

# %%
X = veriseti.iloc[:, 1:6].values
print("X:",X)

y = veriseti.iloc[:, 6].values
print("y:",y)
# Out:
# X: [[ 2.036e+03  7.590e+00  1.465e+01  2.300e-01 -7.060e-01]
#  [ 2.022e+03  7.520e+00  1.228e+01  3.200e-01 -4.760e-01]
#  [ 2.023e+03  7.430e+00  1.241e+01  3.100e-01 -4.980e-01]
#  ...
#  [ 1.998e+03  3.598e+01  4.700e+00 -2.450e+00  3.128e+00]
#  [ 1.997e+03  3.644e+01  4.790e+00 -2.310e+00  3.165e+00]
#  [ 1.995e+03  3.717e+01  4.970e+00 -2.010e+00  3.220e+00]]
# y: [-0.682 -0.444 -0.467 ...  2.884  2.934  3.019]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
#lr adında bir lineer regresyon nesnesi oluşturuldu.
lr=LinearRegression()
#
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#veriseti=veriseti.rename(columns={"country_code":"Ülke Kodu","country_name":"Ulke Adı","year":"Yıl"})

# %%
#df_filtered = df[(df['Industry']=='Tech')&(df['Shares']>=100)]

# %%
#Verisetindeki ülke sayısı tespit edildi.Ayrıca herbir ülkedeb kaçar adet olduğu bulundu.
veriseti['Ulke Adı'].value_counts()

#sorted(veriseti['Ulke Adı'])
# Out:
# Bhutan                 101
# Djibouti               101
# Nigeria                 98
# Guinea                  96
# Cambodia                89
#                       ...
# Virgin Islands U.S.     51
# Sudan                   43
# South Sudan             43
# Puerto Rico             41
# United States           40
# Name: Ulke Adı, Length: 228, dtype: int64

# %%
veriseti['Ulke Adı']
# Out:
# 0               Slovenia
# 1               Slovenia
# 2               Slovenia
# 3               Slovenia
# 4               Slovenia
#               ...
# 15104    Solomon Islands
# 15105    Solomon Islands
# 15106    Solomon Islands
# 15107    Solomon Islands
# 15108    Solomon Islands
# Name: Ulke Adı, Length: 15109, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
from sklearn.compose import ColumnTransformer
encoder = LabelEncoder()

# %%
X[:, 0] = encoder.fit_transform(veriseti['Ulke Adı'])

# %%
data = pd.get_dummies(veriseti)

# %%
veriseti = pd.get_dummies(veriseti, columns =['Ulke Adı'])

# %%
veriseti
# Out:
#         Yıl  Kaba Doğum Oranı  Gerçek Ölüm Oranı  Net Göç  Doğal Artış Oranı  \
# 0      2036              7.59              14.65     0.23             -0.706
# 1      2022              7.52              12.28     0.32             -0.476
# 2      2023              7.43              12.41     0.31             -0.498
# 3      2024              7.35              12.55     0.31             -0.520
# 4      2025              7.30              12.68     0.30             -0.538
# ...     ...               ...                ...      ...                ...
# 15104  2000             34.93               4.53    -2.51              3.040
# 15105  1999             35.48               4.61    -2.58              3.087
# 15106  1998             35.98               4.70    -2.45              3.128
# 15107  1997             36.44               4.79    -2.31              3.165
# 15108  1995             37.17               4.97    -2.01              3.220
#
# ...

# %%
X = veriseti.iloc[:, 0:5].values
y = veriseti.iloc[:, 5].values
print('X:',X)
print('Y:',y)
# Out:
# X: [[ 2.036e+03  7.590e+00  1.465e+01  2.300e-01 -7.060e-01]
#  [ 2.022e+03  7.520e+00  1.228e+01  3.200e-01 -4.760e-01]
#  [ 2.023e+03  7.430e+00  1.241e+01  3.100e-01 -4.980e-01]
#  ...
#  [ 1.998e+03  3.598e+01  4.700e+00 -2.450e+00  3.128e+00]
#  [ 1.997e+03  3.644e+01  4.790e+00 -2.310e+00  3.165e+00]
#  [ 1.995e+03  3.717e+01  4.970e+00 -2.010e+00  3.220e+00]]
# Y: [-0.682 -0.444 -0.467 ...  2.884  2.934  3.019]

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
encoder = LabelEncoder()

# %%
#X[:, 0] = encoder.fit_transform(veriseti['Ulke Adı'])

# %%
onehotencoder = ColumnTransformer([("Ulke Adı", OneHotEncoder(), [0])], remainder = 'passthrough')

# %%
X = onehotencoder.fit_transform(X)
X.toarray()
# Out:
# array([[ 0.   ,  0.   ,  0.   , ..., 14.65 ,  0.23 , -0.706],
#        [ 0.   ,  0.   ,  0.   , ..., 12.28 ,  0.32 , -0.476],
#        [ 0.   ,  0.   ,  0.   , ..., 12.41 ,  0.31 , -0.498],
#        ...,
#        [ 0.   ,  0.   ,  0.   , ...,  4.7  , -2.45 ,  3.128],
#        [ 0.   ,  0.   ,  0.   , ...,  4.79 , -2.31 ,  3.165],
#        [ 0.   ,  0.   ,  0.   , ...,  4.97 , -2.01 ,  3.22 ]])

# %%
#veriseti['Ulke Adı'] = encoder.fit_transform(veriseti['Ulke Adı'])

# %%
veriseti.head()
# Out:
#     Yıl  Kaba Doğum Oranı  Gerçek Ölüm Oranı  Net Göç  Doğal Artış Oranı  \
# 0  2036              7.59              14.65     0.23             -0.706
# 1  2022              7.52              12.28     0.32             -0.476
# 2  2023              7.43              12.41     0.31             -0.498
# 3  2024              7.35              12.55     0.31             -0.520
# 4  2025              7.30              12.68     0.30             -0.538
#
#    Büyüme Oranı  Ulke Adı_Afghanistan  Ulke Adı_Albania  Ulke Adı_Algeria  \
# 0        -0.682                     0                 0                 0
# 1        -0.444                     0                 0                 0
# 2        -0.467                     0                 0                 0
# 3        -0.489                     0                 0                 0
# 4        -0.508                     0                 0                 0
#
#    Ulke Adı_American Samoa  ...  Ulke Adı_Venezuela  Ulke Adı_Vietnam  \
# ...

# %%
X = veriseti.iloc[:, :5].values
print("X:",X)

y = veriseti.iloc[:, 5].values
print("y:",y)
# Out:
# X: [[ 2.036e+03  7.590e+00  1.465e+01  2.300e-01 -7.060e-01]
#  [ 2.022e+03  7.520e+00  1.228e+01  3.200e-01 -4.760e-01]
#  [ 2.023e+03  7.430e+00  1.241e+01  3.100e-01 -4.980e-01]
#  ...
#  [ 1.998e+03  3.598e+01  4.700e+00 -2.450e+00  3.128e+00]
#  [ 1.997e+03  3.644e+01  4.790e+00 -2.310e+00  3.165e+00]
#  [ 1.995e+03  3.717e+01  4.970e+00 -2.010e+00  3.220e+00]]
# y: [-0.682 -0.444 -0.467 ...  2.884  2.934  3.019]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 43)

# %%
model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# [-0.38401206  3.34406717  2.59956898 ...  3.0643713   1.10412927
#   0.26880606]

# %%
input_data = ([[2020,7.43,12.41,0.31,-0.498]])

# %%
input_data_as_numpy = np.array(input_data)

# %%
pediction = model.predict(input_data_as_numpy)

# %%
print(pediction)
# Out:
# [-0.56251846]

# %%
model.predict([[1997,36.44,4.79,-2.31,3.165]])
# Out:
# array([3.15722763])

# %%
#lr adında bir lineer regresyon nesnesi oluşturuldu.
lr=LinearRegression()
#
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score # r kare
from sklearn.linear_model import LinearRegression # doğrusal
import matplotlib.pyplot as plt

# %%
yeni_tahmin=lr.predict(X)

yeni_tahmin.reshape(1,-1)
# Out:
# array([[-0.85332199, -0.54180671, -0.56822655, ...,  3.12255072,
#          3.15722763,  3.20864617]])

# %%
plt.scatter(y,yeni_tahmin)

plt.ylabel("tahmin")
plt.xlabel("Büyüme Oranı")
plt.title("Nüfus Sayısı-Büyüme Oranı İlişkisi")
plt.grid(True)
plt.show()

# %%
print("R2 score hata oranı:",r2_score(y,yeni_tahmin))
# Out:
# R2 score hata oranı: 0.12860327090629753
